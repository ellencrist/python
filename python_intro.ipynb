# %% [markdown]
# <a href="https://colab.research.google.com/github/ellencrist/python/blob/main/python_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Python: Conhecendo a Linguagem

# %% [markdown]
# # O que é Programação?

# %% [markdown]
# ## O que é um programa de computador?
# ## O que é um algoritmo?

# %% [markdown]
# # Um pouco mais Sobre o Python

# %% [markdown]
# ## O que programar? (aplicações)
# ## Aonde programar? (ambientes)
# ## Como instalar o interpretador?

# %% [markdown]
# # A linguagem ("Hello World")

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# #Tipos de Dados básicos

# %%
print(type(5)) # O tipo do número 2 é int (número inteiro)"
print(type(2.5)) # O tipo do número 2.5 é float (número decimal)
print(type(1.5+1.5j)) # O tipo do número 1 + 1j (j é o número imaginário) é complex
print(type("O termo termo esta entre aspas")) # Sequencia de caracteres para armazenar texto
print(type(True)) # tipo booleano para Verdadeiro (True) e Falso (False)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ## Variáveis
#
# Uma variável não pode ter o nome comçado por números, eveitmem palavras-chave da linaguagem e caracateres especiais

# %%
# nome_da_variavel = valor
altura_do_guilherme =  1.80 
texto = "Hello world"
chovendo = True
sabor_bolo = "de Fubá"
sabao = 1

# %%
print(altura_do_guilherme)
# Out:
# 1.8

# %% [markdown]
# ## Operações básicas (e nem tão básicas)

# %% [markdown]
# ### Com dados numéricos

# %%
print(1 + 2) # o '+' é a soma usual
print(10.5 - 1.5) # o '-' é a subtração usual
print(2 * -2) # o '*' é a multiplicação usual
print(9/ 3) # o '/' é a divisão usual

print(4 ** -0.15613216) # o '**' é a exponenciação
print( 10// 3) # o '//' é o quociente da divisão inteira
print(10 % 3) # o '%' é o resto da divisão inteiro
# Out:
# 3
# 9.0
# -4
# 3.0
# 0.8053767223171078
# 3
# 1

# %% [markdown]
# ### Com dados texto

# %%
turno = "tarde"
resultado = "Boa " + turno # o '+' é a concatenação de strings

# %%
 '2' * 3# o '*' repete a string x vezes onde x é um número inteiro
# Out:
# '222'

# %% [markdown]
# ### Com booleanos

# %%
False - 10 # converte o True para 1 e o False para 0 e faz numericamente
# Out:
# -10

# %% [markdown]
# ## Conversão de tipos de Dados

# %%
# conversão de tipos de Dados

string = "10.5"
numero = float(string)
numero + 10

# %%
10 + float('10')
# Out:
# 20.0

# %% [markdown]
# ## Exercícios

# %%
## Escreva uma sequência de operações em python que converta uma medida em polegadas para centimetros -> 1pol = 2.54cm

# %%
# transforma centimetros em polegadas

# %%
### Escreva uma sequência de operações em python que converta um valor em real para dólar -> 1 dol = 5.12 real

# %%
## Escreva uma sequência de operações em python que converta um valor em dólar para real

valor_dolar = float(input("Digite o valor em dólar: "))
valor_real = valor_dolar * 5.12
print(f"$ {valor_dolar:.2f} é equivalente a R$ {valor_real:.2f}")
# Out:
# Digite o valor em dólar: 13.63
# $ 13.63 é equivalente a R$ 69.79

# %%
# Out:
# 13

# %%
## Exercicio Conversão de Celsius para Fahrenheit
##  C * 9/5  + 32 = F 

# C = 0;   F = 32
# C 100; F = 212
# C = -10; F = 14

temperatura_celsius = float(input("Informe a temperatura em Celsius: "))
temperatura_fahrenheit = 32 + temperatura_celsius * 9 / 5 
print(f'{temperatura_celsius:.2f}ºC é equivalente a {temperatura_fahrenheit:.2f}ºF')
# Out:
# Informe a temperatura em Celsius: 100
# 100.00ºC é equivalente a 212.00ºF

# %% [markdown]
# # Desvios condicionais

# %%
# Operadores de Comparação 

print(f"3 == 3: {3 == 3}") # '==' representa igualdade 
print('"Texto" == "texto":', "texto" == "Texto")
print('"2.34" == 2.34:', "2.34" == 2.34)
variavel = 5
print("2*variavel == 10:", 2*variavel == 10)

print("2 > 3:", 2 > 3) # '>' verifica se o número a esquerda do símbolo é maior que o da direita
print("2 > 2:", 2 > 2)
print("2 < 3:", 2 < 3) # '<' verifica se o número a esquerda do símbolo é menor que o da direita
print("2 < 2:", 2 < 2)
print("Zulu< abacate:", "Zulu" < "abacate")

print("2 >= 3:", 2 >= 3) # '>=' verifica se o número a esquerda do símbolo é maior ou igual que o da direita
print("2 >= 2:", 2 >= 2)
print("2 <= 3:", 2 <= 3) # '<=' verifica se o número a esquerda do símbolo é menor ou igual que o da direita
print("2 <= 2:", 2 <= 2)
print("abacaxi <= abacate:", "abacaxi" <= "abacate")

print("3 != 2:", 3 != 2) # '!=' verifica se os números são diferentes 
print("2 != 2:", 2 != 2) # '!=' verifica se os números são diferentes 
print('"Texto" != "texto":', "Texto" != "texto")
# Out:
# 3 == 3: True
# "Texto" == "texto": False
# "2.34" == 2.34: False
# 2*variavel == 10: True
# 2 > 3: False
# 2 > 2: False
# 2 < 3: True
# 2 < 2: False
# Zulu< abacate: True
# 2 >= 3: False
# 2 >= 2: True
# 2 <= 3: True
# 2 <= 2: True
# abacaxi <= abacate: False
# 3 != 2: True
# 2 != 2: False
# "Texto" != "texto": True

# %% [markdown]
# if condicao:
#   codigo para executar quando a consiçãão for verdadeira
#   mais codigo
#   mais codigo
# outros códigos que não dependem da condição

# %%
media = 5

# %%
if media < 5:
  if media < 3:
    print("Reprovado")
  else:
    print("recuperação")
else:
  if media == 10:
    print("aprovado com louvor")
  else:
    print("aprovado")
# Out:
# é menor que 10
# é maior ou igual que 10
# acabou o if
# 15

# %%
if media < 3:
  print("Reprovado")
if 3 <= media < 5:
  print("recuperação")
if 5 <= media < 10:
  print("aprovado")
if media == 10:
  print("aprovado com louvor")

# %%
if media == 10:
  print("aprovado com louvor")
else:
  if media >= 5:
    print("aprovado")
  else:
    if media < 3:
      print("reprovado")
    else:
      print("recuperação")

# %%
comando = input("Digite:\n 'p' para converter de polegadas para centimetros\n 'c' caso contrario\n 's' para sair ")
if comando == 'p' or comando == 'P':
  polegadas = float(input("Digite a medida em polegadas: "))
  centimetros = polegadas * 2.54
  print(f"A conversão deu {centimetros:.3f} centimetros")
elif comando == 'c': 
  centimetros = float(input("Digite a medida em centimetros: "))
  polegadas = centimetros / 2.54
  print(f"A conversão deu {polegadas:.3f} polegadas")
elif comando == "s":
  pass
else:
  print("Comando inválido!")

# %%
#

# a*x² + b*x + c = 0
# x² - x + 1 = 0 -> delta = -3 < 0
# x² +2x + 1 = 0 -> delta = 0
# x^2 - 4x = 0 - > delta = 16 > 0

# %%
##  Carro flex 

## se o valor etanol for maior que 70% do valor do valor gasolina -> gasolina
## se o valor do etanol for menor ou igual a 70% do valor gasolina -> etanol


#gasolina, etanol = 4, 1 # etanol
#gasolina, etanol = 4, 3 # gasolina
#gasolina, etanol = 10, 7 # etanol
#gasolina, etanol = 10, 7.0000000001 #gasolina

# %% [markdown]
# ### Exercicio
# dada a tabela o IR, faça um programa que recebe o salário de um trabalhador e devolve o valor do imposto. Utilizando a regra de imposto efetiva até 2021
#
# |Base de cálculo (R$)	|Alíquota (%)|
# --------------------- |-------------|
# |Abaixo de 1.903,98    | 0%  |
# |De 1.903,99 até 2.826,65|	7,5%	|
# |De 2.826,66 até 3.751,05|	15%	|
# |De 3.751,06 até 4.664,68|	22,5%	|
# |Acima de 4.664,69|	27,5%|

# %%
salario = float(input("Digite se salário: "))

if salario < 1903.99:
  aliquota = 0
elif salario < 2826.66:
  aliquota = 0.075
elif salario < 3751.06:
  aliquota = 0.15
elif salario < 4664.69:
  aliquota = 0.225
else:
  aliquota = 0.275

imposto = max(salario * aliquota - 10, 0)
if imposto == 0:
  print("Isento")
else:
  print(f"o valor do imposto é: R$ {imposto:.2f}")
# Out:
# Digite se salário: 1000
# o valor do imposto é: R$ 0.00

# %% [markdown]
# # Laços de repetição

# %% [markdown]
# ## While (enquanto)

# %% [markdown]
# while condição:
#   executa código para a condição verdadeira

# %%
numero = 1 # inicialização 
while numero != 10: # condição de repetição
  print(numero)
  numero = numero + 2 # atualização da da variável
print("acabo")
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# 266833
# 266835
# 266837
# 266839
# 266841
# 266843
# 266845
# 266847
# 266849
# 266851
# 266853
# 266855
# 266857
# 266859
# 266861
# 266863
# 266865
# 266867
# 266869
# 266871
# 266873
# 266875
# 266877
# 266879
# 266881
# 266883
# 266885
# 266887
# 266889
# 266891
# 266893
# 266895
# 266897
# 266899
# 266901
# 266903
# 266905
# 266907
# 266909
# 266911
# 266913
# 266915
# 266917
# 266919
# 266921
# 266923
# 266925
# 266927
# 266929
# 266931
# 266933
# 266935
# 266937
# 266939
# 266941
# 266943
# 266945
# 266947
# 266949
# 266951
# 266953
# 266955
# 266957
# 266959
# 266961
# 266963
# 266965
# 266967
# 266969
# 266971
# 266973
# 266975
# 266977
# 266979
# 266981
# 266983
# 266985
# 266987
# 266989
# 266991
# 266993
# 266995
# 266997
# 266999
# 267001
# 267003
# 267005
# 267007
# 267009
# 267011
# 267013
# 267015
# 267017
# 267019
# 267021
# 267023
# 267025
# 267027
# 267029
# 267031
# 267033
# 267035
# 267037
# 267039
# 267041
# 267043
# 267045
# 267047
# 267049
# 267051
# 267053
# 267055
# 267057
# 267059
# 267061
# 267063
# 267065
# 267067
# 267069
# 267071
# 267073
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-d090f7e653e9> in <module>
#       1 numero = 1 # inicialização
#       2 while numero != 10: # condição de repetição
# ----> 3   print(numero)
#       4   numero = numero + 2 # atualização da da variável
#       5 print("acabo")
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     616                 )
#     617             data.group = group
# --> 618         return super().send(data, flags=flags, copy=copy, track=track)
#     619
#     620     def send_multipart(
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
# Faça um programa em python que lê palavras digitadas pelo usuário até que ele digite "sair". 
# Depois informe quantas palavras ela digitou

frase = "Digite uma palavra qualquer ou 'sair' para sair (alterei): "
qtd_palavras = 0
palavra = input(frase)
while palavra != "sair" and qtd_palavras < 5:
  palavra = input(frase)
  qtd_palavras = qtd_palavras + 1
print(f"Você digitou {qtd_palavras} palavras")
# Out:
# Digite uma palavra qualquer ou 'sair' para sair (alterei): sair
# Você digitou 0 palavras

# %%
# fazer um código python que calcula x^y

# %%
## Le números do usuário até ele digitar o numero -1 (ok)
## calcula a média dos números digitados

qtd_numeros = 0
soma = 0
numero = float(input("Digite um número ou '-1' para sair: "))
while numero != -1:
  soma = soma + numero
  qtd_numeros = qtd_numeros + 1
  numero = float(input("Digite um número ou '-1' para sair: "))

if(qtd_numeros == 0):
  print("Você não digitou nenhum número")
else:
  media = soma/qtd_numeros
  print(f"A média dos números digitados é: {media}")
# Out:
# Digite um número ou '-1' para sair: -1
# Você não digitou nenhum número

# %%
## Calcule o fatorial de um número

# %% [markdown]
# # Coleções de dados

# %% [markdown]
# ### Listas

# %%
lista = ["ola", "alo", 1, 1.34, True]

# %%
print(lista)
# Out:
# ['ola', 'alo', 1, 1.34, True]

# %%
# acessar um elemento da lista
lista[4]# em uma lista com N elementos os indices vão de 0 até N-1
# Out:
# True

# %%
lista[2.1] = "novo valor"
print(lista)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-c57d6e34eccb> in <module>
# ----> 1 lista[2.1] = "novo valor"
#       2 print(lista)
#
# TypeError: list indices must be integers or slices, not float

# %%
len(lista) # devolve o numero de elementos em uma coleção
# Out:
# 5

# %%
lista[0] = "pudim"
print(lista)
# Out:
# ['pudim', 'ola', 'novo valor', 1.34, True, 'novo elemento']

# %%
lista.append("novo elemento")
print(lista)
# Out:
# ['pudim', 'ola', 'novo valor', 1.34, True, 'novo elemento']

# %%
lista.insert(0, 'inicio')
print(lista)
# Out:
# ['inicio', 'pudim', 'ola', 'novo valor', 10, 1.34, True, 'novo elemento']

# %%
lista.index(1.34)
# Out:
# 5

# %%
deletado = lista.pop()
print(lista)
print(deletado)
# Out:
# ['pudim', 'ola', 10, 1.34, True]
# novo elemento

# %%
del(lista)
print(lista)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-317e968b8c36> in <module>
#       1 del(lista)
# ----> 2 print(lista)
#
# NameError: name 'lista' is not defined

# %%
lista2 = []
print(lista2)
# Out:
# []

# %%
lista2.append("pudim")
print(lista2)
# Out:
# ['hello', 'pudim']

# %%
lista = [1,2,3]
lista[1] ** 2
# Out:
# 4

# %%
## Modifique o algoritmo que calculava a média dos números
## para encontrar a mediana dos valores
## dica: Use listas par guardar todos os valores informados

# como calcular a mediana
# ordenamos os valores do menos para o maior
# se tem núúmeo impar de valores a mediana é o valor do meio
#[ 5 , 1,2] -> [1,2,5] -> 2
# Se tem um numero par de valores, a mediana é a media dos 2 centrais
#[ 5 , 1, 4,2] -> [1,2,4,5]- > 3 = (2+4)/2


numeros = []
numero = float(input("digite um número ou '-1' para sair: "))
while not numero == -1:
  numeros.append(numero)
  numero = float(input("digite um número ou '-1' para sair: "))

numeros_ordenados = sorted(numeros)
if len(numeros) % 2 == 1:
  meio = len(numeros_ordenados) // 2
  mediana = numeros_ordenados[meio]
else:
  meio1 = len(numeros_ordenados) // 2
  meio2 = meio1 -1
  mediana = (numeros_ordenados[meio1] + numeros_ordenados[meio2])/2

print(mediana)
# Out:
# digite um número ou '-1' para sair: 4
# digite um número ou '-1' para sair: 1
# digite um número ou '-1' para sair: 3
# digite um número ou '-1' para sair: 2
# digite um número ou '-1' para sair: -1
# 2.5

# %%
help(sorted)
# Out:
# Help on built-in function sorted in module builtins:
#
# sorted(iterable, /, *, key=None, reverse=False)
#     Return a new list containing all items from the iterable in ascending order.
#
#     A custom key function can be supplied to customize the sort order, and the
#     reverse flag can be set to request the result in descending order.

# %% [markdown]
# ### For (para cada)

# %%
lista = [1,4,5,6,7]
indice = 0
while indice < len(lista):
  print(lista[indice])
  indice = indice + 1
# Out:
# 1
# 4
# 5
# 6
# 7

# %%
for num in [1,4,5,6,7]:
  print(num)
print("acabou")
# Out:
# 1
# 4
# 5
# 6
# 7
# acabou

# %% [markdown]
# ## Dicionários

# %%
nome = 'asdrubal'
dicionario = {nome: 'Guilherme', 'matricula': 123456, 'cpf': 0 , 1: ['isso', 'é', 'uma lista']}
lista = ['Guilherme',123456, 0,0,0,0,0,0,0,0]

# %%
lista[0]

# %%
dicionario[0]

# %%
dicionario['altura'] = 1.8

# %%
len(dicionario)

# %%
dicionario

# %%
dicionario['rg']

# %%
dicionario['notas'] = {'matematica': [5,6.5,7], 'historia': [1,2]}

# %%
dicionario

# %%
dicionario['notas']['historia'][1]

# %%
alunos = [{'nome': 'Guilherme', 'notas': {'historia': [1, 3, 8] }},{'aluno': 'Gabriel'} ,{'aluno': 'Bianca'}]

# %%
if 'ingles' in alunos[0]['notas']:
  print("ja tem a nota")

# %%
print(dicionario)

# %%
for chave, valor in dicionario.items():
  print(chave, valor)

# %% [markdown]
# ## Tuplas

# %%
t = (1,2, 3)

# %%
t[0] = 10

# %% [markdown]
# # Funções

# %%
def diz_ola(nome):
  print('Olá')
  print('tudo bem?')
  print(nome)
